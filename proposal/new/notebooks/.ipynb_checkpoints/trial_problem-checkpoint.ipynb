# %% [markdown]
# ## 踩坑记录
#
# 之前在 MNIST 专家级教程中声明了 dropout 的 placeholder（占位符）（名为 `keep_prob`），后面在文本分类的前期试验中照搬代码，却以为自己没用上这个占位符，于是没给它喂数据；同时，在前后两份出问题的实验中，在声明所有的 placeholder 时都没有定义 name 参数，以至于即便输出了 INFO 级别的日志，也不知道 TF 究竟是需要我哪个参数。
#
# 所以，以后在声明什么 tf.placeholder(, tf.Variable, tf.constant) 时都要加 name 参数啊，以便能根据输出日志追踪。
#
# > 听说最好还加上 name scpoe 方便用 TensorBoard。还没研究 TFBoard，先记下来。

# %%
# Step 0: import module

import os
import tensorflow as tf
import pandas as pd
import numpy as np
from IPython.display import display
# %matplotlib inline

print "import modules successfully"
# Out:
# import modules successfully

# %% [markdown]
# ### CNN trial

# %%
# if wanna read data from CSV file

df = {}

for tpart in ['train', 'test']:
    csvpath = os.path.join(os.getcwd(), 'data_CSV', '{}.csv'.format(tpart))
    if os.path.exists(csvpath):
        df[tpart] = pd.DataFrame.from_csv(csvpath)
        df[tpart] = df[tpart].sample(frac=1)
        df[tpart].reset_index(drop=True, inplace=True)
        print "read {} successfully".format(tpart)
        display(df[tpart])
# Out:
# read train successfully
#              0         1    2         3         4         5         6  \
# 0     0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 1     0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2     0.000000  0.164590  0.0  0.000000  0.000000  0.000000  0.000000
# 3     0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 4     0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 5     0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 6     0.000000  0.000000  0.0  0.173410  0.000000  0.000000  0.000000
# 7     0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 8     0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 9     0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 10    0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 11    0.000000  0.000000  0.0  0.008740  0.011514  0.000000  0.000000
# 12    0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 13    0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 14    0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 15    0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 16    0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 17    0.000000  0.000000  0.0  0.000000  0.247841  0.000000  0.000000
# 18    0.000000  0.109789  0.0  0.000000  0.000000  0.000000  0.000000
# 19    0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 20    0.000000  0.114846  0.0  0.000000  0.000000  0.000000  0.000000
# 21    0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 22    0.133905  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 23    0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 24    0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 25    0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 26    0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 27    0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 28    0.000000  0.000000  0.0  0.000000  0.000000  0.059874  0.000000
# 29    0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# ...        ...       ...  ...       ...       ...       ...       ...
# 2220  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.017656
# 2221  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2222  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2223  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2224  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2225  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2226  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2227  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2228  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2229  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2230  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2231  0.000000  0.000000  0.0  0.201602  0.000000  0.000000  0.000000
# 2232  0.000000  0.184910  0.0  0.083454  0.000000  0.000000  0.000000
# 2233  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2234  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2235  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2236  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2237  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2238  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2239  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2240  0.000000  0.069802  0.0  0.000000  0.000000  0.000000  0.000000
# 2241  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2242  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2243  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2244  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2245  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2246  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2247  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2248  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2249  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
#
#              7         8    9           ...                  775       776  \
# 0     0.000000  0.000000  0.0           ...             0.000000  0.000000
# 1     0.000000  0.000000  0.0           ...             0.000000  0.163977
# 2     0.000000  0.000000  0.0           ...             0.000000  0.000000
# 3     0.000000  0.000000  0.0           ...             0.000000  0.000000
# 4     0.000000  0.000000  0.0           ...             0.000000  0.000000
# 5     0.000000  0.000000  0.0           ...             0.000000  0.000000
# 6     0.000000  0.000000  0.0           ...             0.000000  0.000000
# 7     0.000000  0.000000  0.0           ...             0.000000  0.000000
.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.566880
# ...        ...  ...       ...       ...       ...       ...       ...
# 2220  0.000000  0.0  0.000000  0.000000  0.042066  0.022101  0.333238
# 2221  0.000000  0.0  0.000000  0.113378  0.000000  0.000000  0.000000
# 2222  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.085683
# 2223  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2224  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.085073
# 2225  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2226  0.000000  0.0  0.000000  0.083287  0.000000  0.000000  0.031770
# 2227  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.487651
# 2228  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.117280
# 2229  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2230  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.077544
# 2231  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.625907
# 2232  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2233  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.333174
# 2234  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2235  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.072052
# 2236  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2237  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.375765
# 2238  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2239  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.603232
# 2240  0.000000  0.0  0.000000  0.064102  0.000000  0.000000  0.000000
# 2241  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.080734
# 2242  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.529496
# 2243  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.135872
# 2244  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2245  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2246  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.143720
# 2247  0.000000  0.0  0.000000  0.207284  0.000000  0.000000  0.000000
# 2248  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.147014
# 2249  0.000000  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                         class
# 0                misc.forsale
# 1                misc.forsale
# 2                 alt.atheism
# 3     comp.os.ms-windows.misc
# 4                 alt.atheism
# 5                misc.forsale
# 6                misc.forsale
# 7                     sci.med
# 8                misc.forsale
# 9                     sci.med
# 10                alt.atheism
# 11                    sci.med
# 12    comp.os.ms-windows.misc
# 13               misc.forsale
# 14                    sci.med
# 15                alt.atheism
# 16               misc.forsale
# 17               misc.forsale
# 18               misc.forsale
# 19                alt.atheism
# 20                alt.atheism
# 21                    sci.med
# 22    comp.os.ms-windows.misc
# 23    comp.os.ms-windows.misc
# 24    comp.os.ms-windows.misc
# 25                alt.atheism
# 26                alt.atheism
# 27                alt.atheism
# 28    comp.os.ms-windows.misc
# 29               misc.forsale
# ...                       ...
# 2220              alt.atheism
# 2221              alt.atheism
# 2222  comp.os.ms-windows.misc
# 2223                  sci.med
# 2224              alt.atheism
# 2225              alt.atheism
# 2226                  sci.med
# 2227              alt.atheism
# 2228                  sci.med
# 2229                  sci.med
# 2230  comp.os.ms-windows.misc
# 2231             misc.forsale
# 2232  comp.os.ms-windows.misc
# 2233             misc.forsale
# 2234                  sci.med
# 2235              alt.atheism
# 2236  comp.os.ms-windows.misc
# 2237             misc.forsale
# 2238                  sci.med
# 2239                  sci.med
# 2240              alt.atheism
# 2241  comp.os.ms-windows.misc
# 2242             misc.forsale
# 2243             misc.forsale
# 2244                  sci.med
# 2245              alt.atheism
# 2246  comp.os.ms-windows.misc
# 2247              alt.atheism
# 2248                  sci.med
# 2249             misc.forsale
#
# [2250 rows x 785 columns]
# read test successfully
#              0         1         2         3    4         5         6  \
# 0     0.000000  0.000000  0.038366  0.000000  0.0  0.000000  0.000000
# 1     0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 2     0.083343  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 3     0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 4     0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 5     0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 6     0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 7     0.057883  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 8     0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 9     0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 10    0.000000  0.261827  0.000000  0.000000  0.0  0.000000  0.131209
# 11    0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 12    0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 13    0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 14    0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 15    0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 16    0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 17    0.000000  0.000000  0.000000  0.000000  0.0  0.161226  0.000000
# 18    0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 19    0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.072031
# 20    0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 21    0.057130  0.059115  0.000000  0.000000  0.0  0.054578  0.000000
# 22    0.000000  0.000000  0.134701  0.000000  0.0  0.000000  0.000000
# 23    0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
#
0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1477  0.000000  0.071526  0.000000  0.000000  0.000000  0.000000  0.00000
# 1478  0.000000  0.000000  0.000000  0.059818  0.000000  0.000000  0.00000
# 1479  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1480  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1481  0.177483  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1482  0.177745  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1483  0.048657  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1484  0.000000  0.067826  0.000000  0.000000  0.075714  0.000000  0.00000
# 1485  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1486  0.074023  0.122878  0.000000  0.035381  0.000000  0.000000  0.00000
# 1487  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1488  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1489  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1490  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1491  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1492  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1493  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1494  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1495  0.000000  0.000000  0.000000  0.000000  0.337030  0.000000  0.00000
# 1496  0.000000  0.128612  0.000000  0.000000  0.071784  0.000000  0.00000
# 1497  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1498  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
#
#            783                    class
# 0     0.074116              alt.atheism
# 1     0.000000                  sci.med
# 2     0.070490              alt.atheism
# 3     0.205035             misc.forsale
# 4     0.165959             misc.forsale
# 5     0.283339             misc.forsale
# 6     0.299130                  sci.med
# 7     0.377661  comp.os.ms-windows.misc
# 8     0.194321  comp.os.ms-windows.misc
# 9     0.467794             misc.forsale
# 10    0.091719             misc.forsale
# 11    0.243283             misc.forsale
# 12    0.000000                  sci.med
# 13    0.337452                  sci.med
# 14    0.117079                  sci.med
# 15    0.164786  comp.os.ms-windows.misc
# 16    0.027930                  sci.med
# 17    0.000000              alt.atheism
# 18    0.000000              alt.atheism
# 19    0.243366                  sci.med
# 20    0.022369  comp.os.ms-windows.misc
# 21    0.082833  comp.os.ms-windows.misc
# 22    0.000000              alt.atheism
# 23    0.056655                  sci.med
# 24    0.122270  comp.os.ms-windows.misc
# 25    0.529586             misc.forsale
# 26    0.000000                  sci.med
# 27    0.161240  comp.os.ms-windows.misc
# 28    0.102458                  sci.med
# 29    0.035144  comp.os.ms-windows.misc
# ...        ...                      ...
# 1469  0.103505             misc.forsale
# 1470  0.053441              alt.atheism
# 1471  0.241568             misc.forsale
# 1472  0.200634                  sci.med
# 1473  0.101971                  sci.med
# 1474  0.000000                  sci.med
# 1475  0.000000             misc.forsale
# 1476  0.398307             misc.forsale
# 1477  0.152284              alt.atheism
# 1478  0.110576  comp.os.ms-windows.misc
# 1479  0.000000                  sci.med
# 1480  0.000000                  sci.med
# 1481  0.062727             misc.forsale
# 1482  0.062819                  sci.med
# 1483  0.687857             misc.forsale
# 1484  0.115525              alt.atheism
# 1485  0.000000  comp.os.ms-windows.misc
# 1486  0.287776                  sci.med
# 1487  0.000000             misc.forsale
# 1488  0.000000  comp.os.ms-windows.misc
# 1489  0.000000                  sci.med
# 1490  0.052913                  sci.med
# 1491  0.076611                  sci.med
# 1492  0.414770  comp.os.ms-windows.misc
# 1493  0.000000  comp.os.ms-windows.misc
# 1494  0.000000             misc.forsale
# 1495  0.128561              alt.atheism
# 1496  0.164293              alt.atheism
# 1497  0.331960             misc.forsale
# 1498  0.049380  comp.os.ms-windows.misc
#
# [1499 rows x 785 columns]

# %%
from sklearn.preprocessing import LabelBinarizer

csvpath_root = os.path.join(os.getcwd(), 'data_CSV')

df_new = {}

lb = LabelBinarizer()
lb.fit(df['train']['class'])

for tpart in ['train', 'test']:
    labels = lb.transform(df[tpart]['class'])
    labelsDf = pd.DataFrame(labels, columns=["class-{}".format(i) for i in range(len(lb.classes_))])
    df_new[tpart] = {}
    df_new[tpart]['y'] = labelsDf
    df_new[tpart]['x'] = df[tpart].drop('class', axis=1)
    df_new[tpart]['all'] = df_new[tpart]['x'].join(df_new[tpart]['y'])
    #save in CSV
    for subpart in ['x', 'y', 'all']:
        csvpath = os.path.join(csvpath_root, "{}-cleanLabels-{}.csv".format(tpart, subpart))
        df_new[tpart][subpart].to_csv(csvpath)
    
print "label cleaning succussfully"
# Out:
# label cleaning succussfully

# %%
tf.logging.set_verbosity(tf.logging.INFO)

sess = tf.InteractiveSession()

COL_OUTCOME = 'class'
COL_FEATURE = [col for col in list(df['train'].columns) if col != COL_OUTCOME]

count_feature = len(COL_FEATURE)
count_class = len(df['train']['class'].unique())

x = tf.placeholder(tf.float32, shape=[None, 784], name='x')
y_ = tf.placeholder(tf.float32, shape=[None, count_class], name='y_')

W = tf.Variable(tf.zeros([count_feature, count_class]))
b = tf.Variable(tf.zeros([count_class]))
y = tf.matmul(x, W) + b

# %%
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

# %%
def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

# %%
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

# %%
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])
x_text = tf.reshape(x, [-1, 28, 28, 1])
h_conv1 = tf.nn.relu(conv2d(x_text, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])
h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

W_fc1 = weight_variable([7 * 7 * 64, 1024])
b_fc1 = bias_variable([1024])

h_pool2_flat = tf.reshape(h_pool2, [-1, 7 * 7 * 64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

keep_prob = tf.placeholder(tf.float32, name='keep_prob')
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

W_fc2 = weight_variable([1024, count_class])
b_fc2 = bias_variable([count_class])

y_conv = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

# %%
### Start to traini and evaluate the model

cross_entropy = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y_conv))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
sess.run(tf.global_variables_initializer())

# %%
x_input = df_new['train']['x']
x_input = [np.array([
            np.float32(x_input.iloc[i].values)
        ])
    for i in range(x_input.shape[0])]
y_input = df_new['train']['y']
y_input = [np.array([
            np.float32(y_input.iloc[i].values)
        ])
    for i in range(y_input.shape[0])]
# y_input = [np.array([y_input.iloc[i].values]) for i in range(y_input.shape[0])]

# not use random input

for i in range(df['train'].shape[0]):
    if 0 == i % 100:
        train_accuracy = []
        for j in range(50):
            train_accuracy.append(accuracy.eval(feed_dict={
                    keep_prob: 1,
                    x: x_input[i+j],#x_input.iloc[i+j].values, #
                    y_: y_input[i+j]#y_input.iloc[i+j].values #
                })
            )
        print "step {}, training accuracy {}".format(i, np.mean(train_accuracy))
    train_step.run(feed_dict={
        keep_prob: 0.5,
        x:  x_input[i],#x_input.iloc[i].values, #
        y_: y_input[i]#y_input.iloc[i].values#
    })

print "finish CNN"
# Out:
# step 0, training accuracy 0.280000001192
# step 100, training accuracy 0.20000000298
# step 200, training accuracy 0.340000003576
# step 300, training accuracy 0.300000011921
# step 400, training accuracy 0.239999994636
# step 500, training accuracy 0.219999998808
# step 600, training accuracy 0.360000014305
# step 700, training accuracy 0.159999996424
# step 800, training accuracy 0.259999990463
# step 900, training accuracy 0.219999998808
# step 1000, training accuracy 0.479999989271
# step 1100, training accuracy 0.379999995232
# step 1200, training accuracy 0.360000014305
# step 1300, training accuracy 0.319999992847
# step 1400, training accuracy 0.699999988079
# step 1500, training accuracy 0.259999990463
# step 1600, training accuracy 0.280000001192
# step 1700, training accuracy 0.560000002384
# step 1800, training accuracy 0.40000000596
# step 1900, training accuracy 0.40000000596
# step 2000, training accuracy 0.5
# step 2100, training accuracy 0.600000023842
# step 2200, training accuracy 0.439999997616
# finish CNN

# %%
x_input = df_new['test']['x']
x_input = [np.array([
            np.float32(x_input.iloc[i].values)
        ])
    for i in range(x_input.shape[0])]
y_input = df_new['test']['y']
y_input = [np.array([
            np.float32(y_input.iloc[i].values)
        ])
    for i in range(y_input.shape[0])]

for i in range(df['test'].shape[0]):
    if 0 == i % 100:
        train_accuracy = []
        for j in range(50):
            train_accuracy.append(accuracy.eval(feed_dict={
                    keep_prob: 1,
                    x: x_input[i+j],#x_input.iloc[i+j].values, #
                    y_: y_input[i+j]#y_input.iloc[i+j].values #
                })
            )
        print "step {}, training accuracy {}".format(i, np.mean(train_accuracy))

print "finish test for CNN"
# Out:
# step 0, training accuracy 0.660000026226
# step 100, training accuracy 0.72000002861
# step 200, training accuracy 0.639999985695
# step 300, training accuracy 0.620000004768
# step 400, training accuracy 0.620000004768
# step 500, training accuracy 0.72000002861
# step 600, training accuracy 0.620000004768
# step 700, training accuracy 0.660000026226
# step 800, training accuracy 0.620000004768
# step 900, training accuracy 0.479999989271
# step 1000, training accuracy 0.660000026226
# step 1100, training accuracy 0.519999980927
# step 1200, training accuracy 0.560000002384
# step 1300, training accuracy 0.639999985695
# step 1400, training accuracy 0.72000002861
# finish test for CNN

# %%
x_test = df['test'].drop('class', axis=1)
y_test_raw = df['test']['class']
y_test = [[cls2num[labelname]] for labelname in y_test_raw]

# correct_prediction = tf.equal(tf.argmax(y, 1), tf.argmax(y_, 1))
correct_prediction = tf.argmax(y, 1)
# accuracy = tf.reduce_mean(tf.cast(correction_prediction, tf.float32))

np.array(y_test).shape

mmb = correct_prediction.eval(feed_dict={x: x_input, 
                              y_: y_test})


#
